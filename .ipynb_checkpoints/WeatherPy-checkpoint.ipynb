# %%
import requests
import json
import pandas as pd
from config import api_key
import random
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import openweathermapy.core as owm

# %%
settings = {"units": "imperial", "appid": api_key}

maxlatitude, minlatitude = 90, -90
maxlongitude, minlongitude = 180, -180

# %%
weather = []
citynames = []
i=0

while len(weather)<20:
    lat, long = (random.uniform(minlatitude,maxlatitude),random.uniform(minlongitude,maxlongitude))
    if citipy.nearest_city(lat, long).city_name not in citynames:
        try:
            citynames.append(citipy.nearest_city(lat, long).city_name)
            weather.append(owm.get_current(citynames[i],**settings))      
            print(f"Processing City #{i+1}: {weather[i]['name']}")
            i+=1
        except:
            citynames.pop()
# Out:
# Processing City #1: New Norfolk
# Processing City #2: Albany
# Processing City #3: Port-Gentil
# Processing City #4: Mar del Plata
# Processing City #5: Bluff
# Processing City #6: Qaanaaq
# Processing City #7: Mweka
# Processing City #8: Aklavik
# Processing City #9: Ushuaia
# Processing City #10: Saldanha
# Processing City #11: Bambous Virieux
# Processing City #12: Hermanus
# Processing City #13: Vao
# Processing City #14: Ancud
# Processing City #15: Tasiilaq
# Processing City #16: Lekoni
# Processing City #17: Roebourne
# Processing City #18: Carutapera
# Processing City #19: Jumla
# Processing City #20: Agadez

# %%
dataframe = pd.DataFrame()
dataframe['City'] = pd.Series(city['name'] for city in weather)
dataframe['Cloudiness'] = pd.Series(city['clouds']['all'] for city in weather)
dataframe['Country'] = pd.Series(city['sys']['country'] for city in weather)
dataframe['Date'] = pd.Series(city['dt'] for city in weather)
dataframe['Humidity'] = pd.Series(city['main']['humidity'] for city in weather)
dataframe['Lat'] = pd.Series(city['coord']['lat'] for city in weather)
dataframe['Long'] = pd.Series(city['coord']['lon'] for city in weather)
dataframe['Max Temp'] = pd.Series(city['main']['temp_max'] for city in weather)
dataframe['Wind Speed'] = pd.Series(city['wind']['speed'] for city in weather)

# %%
dataframe
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat    Long  \
# 0       New Norfolk          75      AU  1553124134        93 -42.78  147.06
# 1            Albany          20      US  1553124070        23  42.65  -73.75
# 2       Port-Gentil          75      GA  1553122800        88  -0.72    8.78
# 3     Mar del Plata           0      AR  1553124184        84 -46.43  -67.52
# 4             Bluff           0      AU  1553124177        73 -23.58  149.07
# 5           Qaanaaq           8      GL  1553124181        99  77.48  -69.36
# 6             Mweka          56      CD  1553124762        95  -4.85   21.56
# 7           Aklavik          75      CA  1553122800        53  68.22 -135.01
# 8           Ushuaia          75      AR  1553122800        87 -54.81  -68.31
# 9          Saldanha           0      PT  1553124763        62  41.42   -6.55
# 10  Bambous Virieux          75      MU  1553123942        83 -20.34   57.76
# 11         Hermanus          44      ZA  1553123812        96 -34.42   19.24
# 12              Vao           0      EE  1553124764        92  59.10   26.19
# 13            Ancud          92      CL  1553122800        81 -41.87  -73.83
# 14         Tasiilaq           0      GL  1553122200        33  65.61  -37.64
# 15           Lekoni          68      GA  1553124764        93  -1.58   14.26
# 16        Roebourne           8      AU  1553124196        52 -20.77  117.15
# 17       Carutapera          88      BR  1553124765        94  -1.20  -46.02
# 18            Jumla          92      NP  1553124765       100  29.28   82.18
# 19           Agadez           0      NE  1553124766        26  16.97    7.99
#
#     Max Temp  Wind Speed
# 0      62.60       12.75
# 1      51.80       12.75
# 2      80.60        3.36
# 3      54.03        9.10
# 4      82.92        4.41
# 5     -31.11        7.87
# 6      72.21        2.39
# 7      21.20       13.87
# 8      48.20       17.22
# 9      41.52       10.11
# 10     80.60        6.93
# 11     57.99        2.73
# 12     32.70        9.44
# 13     50.00        4.70
# 14     -0.41        2.24
# 15     71.31        2.73
# 16     84.99        4.63
# 17     78.69        5.97
# 18     26.76        1.83
# 19     77.34       10.78

# %%
fig, ax = plt.subplots(1,1)
ax.scatter(dataframe['Lat'],dataframe['Max Temp'], color='b')
ax.set_xlabel('Latitude')
ax.set_title('Latitude versus Temperature')
ax.set_ylabel('Temperature (F)')           
ax.grid()
ax.set_facecolor('xkcd:light grey')

# %%
fig, ax = plt.subplots(1,1)
ax.scatter(dataframe['Lat'],dataframe['Humidity'], color='b')
ax.set_xlabel('Latitude')
ax.set_title('Latitude versus Humidity')
ax.set_ylabel('Humidity (%)')           
ax.grid()
ax.set_facecolor('xkcd:light grey')

# %%
fig, ax = plt.subplots(1,1)
ax.scatter(dataframe['Lat'],dataframe['Cloudiness'], color='b')
ax.set_xlabel('Latitude')
ax.set_title('Latitude versus Cloudiness')
ax.set_ylabel('Cloudiness (%)')           
ax.grid()
ax.set_facecolor('xkcd:light grey')

# %%
fig, ax = plt.subplots(1,1)
ax.scatter(dataframe['Lat'],dataframe['Wind Speed'], color='b')
ax.set_xlabel('Latitude')
ax.set_title('Latitude versus Wind Speed')
ax.set_ylabel('Wind Speed (mph)')           
ax.grid()
ax.set_facecolor('xkcd:light grey')
